# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("creditcard.csv")

# %%
#head, shape, info, describe
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (41683, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41683 entries, 0 to 41682
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    41683 non-null  int64
#  1   V1      41683 non-null  float64
#  2   V2      41683 non-null  float64
#  3   V3      41682 non-null  float64
#  4   V4      41682 non-null  float64
#  5   V5      41682 non-null  float64
#  6   V6      41682 non-null  float64
#  7   V7      41682 non-null  float64
#  8   V8      41682 non-null  float64
#  9   V9      41682 non-null  float64
#  10  V10     41682 non-null  float64
#  11  V11     41682 non-null  float64
#  12  V12     41682 non-null  float64
#  13  V13     41682 non-null  float64
#  14  V14     41682 non-null  float64
#  15  V15     41682 non-null  float64
#  16  V16     41682 non-null  float64
#  17  V17     41682 non-null  float64
#  18  V18     41682 non-null  float64
#  19  V19     41682 non-null  float64
# ...

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  41683.000000  41683.000000  41683.000000  41682.000000  41682.000000
# mean   26208.345609     -0.222499      0.035454      0.711902      0.186781
# std    12721.514541      1.855101      1.599923      1.490121      1.399707
# min        0.000000    -56.407510    -72.715728    -31.103685     -5.172595
# 25%    16853.000000     -0.974000     -0.533197      0.229759     -0.719018
# 50%    31305.000000     -0.240189      0.093834      0.811276      0.185168
# 75%    36289.000000      1.159396      0.740067      1.443056      1.069459
# max    40784.000000      1.960497     16.713389      4.101716     16.491217
#
#                  V5            V6            V7            V8            V9  \
# count  41682.000000  41682.000000  41682.000000  41682.000000  41682.000000
# mean      -0.234719      0.099510     -0.112246      0.044579      0.193708
# ...

# %% [markdown]
# Identify and handle missing values using appropriate strategies with justification

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull(), cbar=True)
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")

data_imputed = pd.DataFrame(
    imputer.fit_transform(data),
    columns=data.columns
)

# %%
data_imputed.isnull().mean()*100
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# Transform categorical data using encoding techniques.

# %%
data.dtypes
#no encoding required
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %% [markdown]
# : Perform feature engineering by creating at least one new feature

# %%
data['Hour'] = (data['Time'] // 3600) % 24

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41683 entries, 0 to 41682
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    41683 non-null  int64
#  1   V1      41683 non-null  float64
#  2   V2      41683 non-null  float64
#  3   V3      41682 non-null  float64
#  4   V4      41682 non-null  float64
#  5   V5      41682 non-null  float64
#  6   V6      41682 non-null  float64
#  7   V7      41682 non-null  float64
#  8   V8      41682 non-null  float64
#  9   V9      41682 non-null  float64
#  10  V10     41682 non-null  float64
#  11  V11     41682 non-null  float64
#  12  V12     41682 non-null  float64
#  13  V13     41682 non-null  float64
#  14  V14     41682 non-null  float64
#  15  V15     41682 non-null  float64
#  16  V16     41682 non-null  float64
#  17  V17     41682 non-null  float64
#  18  V18     41682 non-null  float64
#  19  V19     41682 non-null  float64
# ...

# %% [markdown]
# Perform data analysis and write two meaningful insights.

# %%
data['Class'].value_counts()
# Out:
# Class
# 0.0    41574
# 1.0      108
# Name: count, dtype: int64

# %%
fraud_rate = data['Class'].mean() * 100
#1=fraud 0=not fraud
print(fraud_rate)
# Out:
# 0.25910464948898804

# %% [markdown]
# 1. What does one row represent in the real world?
#
# each row shows transaction of 1 credit card made by a customer which has following coloumns of transaction time,transaction amount,behavior patterns (V1–V28),whether it was fraud or not(target col)
#
#
# 2. Which column is most useful for decision-making and why?
#
# Class col is most useful as it tells us wheather a transaction is fraud or not and this is our target col too as without it we won't be able to train our model to predict whether a transaction is fraud or not.
#
# 3. Which column would you remove before ML modeling? Why?
#
# i would remove Time column beacuse it is irrevalent to preduct  whether a transaction is fraud or not.
#
# 4. What type of bias might exist in this dataset?
#
# class imbalance bias might exist here as in this 76.51% normal and 23.49% fraud thats why this will train model more normal bias that is not fraud.
#
# 5. Is this dataset for classification or regression? Why?
#
# it is classification dataset as in this we clearly see that our target col has two classes that 0 or 1.
